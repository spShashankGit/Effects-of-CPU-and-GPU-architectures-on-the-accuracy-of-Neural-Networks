# %%
#!conda install -y pandas
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mode

# %%
# %load_ext autotime
# Out:
# time: 477 µs (started: 2021-06-07 17:23:24 +02:00)

# %%
def loadDataSet(filename):
    dataset = pd.read_csv(filename,delimiter=",",header=None)
    dataset = dataset.transpose()
    
    avg = 0
    avgLossPerEpoch = []
    max_epoch_num = 150
    avgDeno = len(dataset)/max_epoch_num
    
    for j in range(len(dataset)):
        avg = avg + float(dataset[0][j])
        if(j%avgDeno==0):
            avgLossPerEpoch.append(avg)
            avg = 0
    return avgLossPerEpoch
# Out:
# time: 711 µs (started: 2021-06-07 17:23:25 +02:00)

# %% [markdown]
# ## LR 0.01

# %%
dataset0 = loadDataSet('loss_values_0.csv')
# Out:
# time: 6.01 s (started: 2021-06-07 17:24:00 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.01',fontsize=45)
plt.plot(dataset0[10:90])
plt.show()
# Out:
# time: 176 ms (started: 2021-06-07 17:24:12 +02:00)

# %% [markdown]
# ## LR = 0.02

# %%
dataset1 = loadDataSet('loss_values_1.csv')
# Out:
# time: 6.13 s (started: 2021-06-07 17:26:58 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.02',fontsize=45)
plt.plot(dataset1[40:])
plt.show()
# Out:
# time: 163 ms (started: 2021-06-07 17:27:05 +02:00)

# %% [markdown]
# plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.02',fontsize=45)
# plt.plot(dataset1)
# plt.show()

# %% [markdown]
# ## LR = 0.03

# %%
dataset2 = loadDataSet('loss_values_2.csv')
# Out:
# time: 6.01 s (started: 2021-06-07 17:27:33 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.03',fontsize=45)
plt.plot(dataset2)
plt.show()
# Out:
# time: 157 ms (started: 2021-06-07 17:27:40 +02:00)

# %% [markdown]
# ## LR = 0.04

# %%
dataset3 = loadDataSet('loss_values_3.csv')
# Out:
# time: 6.06 s (started: 2021-06-07 17:27:44 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.04',fontsize=45)
plt.plot(dataset3)
plt.show()
# Out:
# time: 176 ms (started: 2021-06-07 17:27:51 +02:00)

# %% [markdown]
# ## LR = 0.05

# %%
dataset4 = loadDataSet('loss_values_4.csv')
# Out:
# time: 6.03 s (started: 2021-06-07 17:27:54 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.05',fontsize=45)
plt.plot(dataset4)
plt.show()
#gamma = 0.5 [50,100,125]
# gamma = 0.5 [50,75,100,125]
#Better accuracy 
# pypads results
# intial seed (0)
# Out:
# time: 164 ms (started: 2021-06-07 17:28:00 +02:00)

# %% [markdown]
# ## LR = 0.06

# %%
dataset5 = loadDataSet('loss_values_5.csv')
# Out:
# time: 6.08 s (started: 2021-06-07 17:28:03 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.06',fontsize=45)
plt.plot(dataset5)
plt.show()
# Out:
# time: 154 ms (started: 2021-06-07 17:28:09 +02:00)

# %% [markdown]
# ## LR = 0.07

# %%
dataset6 = loadDataSet('loss_values_6.csv')
# Out:
# time: 6.1 s (started: 2021-06-07 17:28:12 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.07',fontsize=45)
plt.plot(dataset6)
plt.show()
# Out:
# time: 169 ms (started: 2021-06-07 17:28:19 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.07',fontsize=45)
plt.plot(dataset6[10:])
plt.axhline(y=(min(dataset6[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset6[10:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 238 ms (started: 2021-06-07 17:28:22 +02:00)

# %% [markdown]
# ## LR = 0.08

# %%
dataset7 = loadDataSet('loss_values_7.csv')
# Out:
# time: 5.98 s (started: 2021-06-07 17:28:27 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.08',fontsize=45)
plt.plot(dataset7)
plt.show()
# Out:
# time: 194 ms (started: 2021-06-07 17:28:35 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.08',fontsize=45)
plt.plot(dataset7[10:])
plt.axhline(y=(min(dataset7[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset7[10:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 190 ms (started: 2021-06-07 17:28:37 +02:00)

# %% [markdown]
# ## LR = 0.09

# %%
dataset8 = loadDataSet('loss_values_8.csv')
# Out:
# time: 5.98 s (started: 2021-06-07 17:28:50 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.09',fontsize=45)
plt.plot(dataset8)
plt.show()
# Out:
# time: 200 ms (started: 2021-06-07 17:28:59 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.09',fontsize=45)
plt.plot(dataset8[10:])
plt.axhline(y=(min(dataset8[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset8[10:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 174 ms (started: 2021-06-07 17:29:02 +02:00)

# %% [markdown]
# ## LR = 0.1

# %%
dataset9 = loadDataSet('loss_values_9.csv')
# Out:
# time: 6 s (started: 2021-06-07 17:29:05 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.1',fontsize=45)
plt.plot(dataset9)
plt.show()
# Out:
# time: 199 ms (started: 2021-06-07 17:29:24 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.1',fontsize=45)
plt.plot(dataset9[30:])
#plt.axhline(y=(min(dataset9[10:])), color='r', linestyle='--')
#plt.axhline(y=(mode(dataset9[10:])), color='g', linestyle='--')
plt.show()

# till 50 epochs
# Out:
# time: 164 ms (started: 2021-06-07 17:44:04 +02:00)

# %% [markdown]
# ## LR = 0.2

# %%
dataset10 = loadDataSet('loss_values_10.csv')
# Out:
# time: 6.04 s (started: 2021-06-07 17:29:41 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.2',fontsize=45)
plt.plot(dataset10)
plt.show()
# Out:
# time: 195 ms (started: 2021-06-07 17:29:51 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.2',fontsize=45)
plt.plot(dataset10[40:80])
plt.axhline(y=(min(dataset10[40:80])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset10[40:80])), color='g', linestyle='--')
plt.show()
# Out:
# time: 177 ms (started: 2021-06-07 17:29:53 +02:00)

# %% [markdown]
# ## LR = 0.3

# %%
dataset11 = loadDataSet('loss_values_11.csv')
# Out:
# time: 5.94 s (started: 2021-06-07 17:30:01 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.3',fontsize=45)
plt.plot(dataset11)
plt.show()
# Out:
# time: 184 ms (started: 2021-06-07 17:30:07 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.3',fontsize=45)
plt.plot(dataset11[110:])
plt.axhline(y=(min(dataset11[110:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset11[110:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 161 ms (started: 2021-06-07 17:30:10 +02:00)

# %% [markdown]
# ## LR = 0.4

# %%
dataset12 = loadDataSet('loss_values_12.csv')
# Out:
# time: 5.97 s (started: 2021-06-07 17:30:15 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.4',fontsize=45)
plt.plot(dataset12)
plt.show()
# Out:
# time: 190 ms (started: 2021-06-07 17:30:27 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.4',fontsize=45)
plt.plot(dataset12[10:])
plt.axhline(y=(min(dataset10[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset10[10:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 147 ms (started: 2021-06-07 17:30:42 +02:00)

# %% [markdown]
# ## LR = 0.5

# %%
dataset13 = loadDataSet('loss_values_13.csv')
# Out:
# time: 6.08 s (started: 2021-06-07 17:30:43 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.5',fontsize=45)
plt.plot(dataset13)
plt.show()
# Out:
# time: 182 ms (started: 2021-06-07 17:30:50 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.5',fontsize=45)
plt.plot(dataset13[10:])
plt.axhline(y=(min(dataset13[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset13[10:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 174 ms (started: 2021-06-07 17:30:50 +02:00)

# %% [markdown]
# ## LR = 0.6

# %%
dataset14 = loadDataSet('loss_values_14.csv')
# Out:
# time: 6.11 s (started: 2021-06-07 17:30:55 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.6',fontsize=45)
plt.plot(dataset14)
plt.show()
# Out:
# time: 183 ms (started: 2021-06-07 17:31:01 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.6',fontsize=45)
plt.plot(dataset14[90:])
plt.axhline(y=(min(dataset14[90:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset14[90:])), color='g', linestyle='--')
plt.show()
# Out:
# time: 159 ms (started: 2021-06-07 17:31:01 +02:00)

# %% [markdown]
# ## LR = 0.7

# %%
dataset15 = loadDataSet('loss_values_15.csv')
# Out:
# time: 5.99 s (started: 2021-06-07 17:31:13 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.7',fontsize=45)
plt.plot(dataset15)
plt.show()
# Out:
# time: 193 ms (started: 2021-06-07 17:31:20 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.7',fontsize=45)
plt.plot(dataset15[10:])
plt.axhline(y=(min(dataset15[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset15[10:])), color='g', linestyle='--')

plt.show()
# Out:
# time: 192 ms (started: 2021-06-07 17:31:23 +02:00)

# %% [markdown]
# ## LR = 0.8

# %%
dataset16 = loadDataSet('loss_values_16.csv')
# Out:
# time: 5.89 s (started: 2021-06-07 17:31:29 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.8',fontsize=45)
plt.plot(dataset16)
plt.show()
# Out:
# time: 183 ms (started: 2021-06-07 17:31:37 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.8',fontsize=45)

plt.plot(dataset16[10:])
plt.axhline(y=(min(dataset16[10:])), color='r', linestyle='--')
plt.axhline(y=(mode(dataset16[10:])), color='g', linestyle='--')

plt.show()
# Out:
# time: 170 ms (started: 2021-06-07 17:31:39 +02:00)

# %% [markdown]
# ## LR = 0.9

# %%
dataset17 = loadDataSet('loss_values_17.csv')
# Out:
# time: 5.97 s (started: 2021-06-07 17:31:41 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.9',fontsize=45)
plt.plot(dataset17)
plt.show()
# Out:
# time: 187 ms (started: 2021-06-07 17:31:47 +02:00)

# %%
plt.figure(figsize=(30, 12)).suptitle('Learning Rate = 0.9',fontsize=45)

plt.plot(dataset17)
#plt.axhline(y=(min(dataset17[52:])), color='r', linestyle='--')

#plt.axhline(y=(mode(dataset17[52:])), color='g', linestyle='--')
#plt.axhline(y=(mode(dataset17[92:])), color='b', linestyle='--')

plt.show()
# Out:
# time: 148 ms (started: 2021-06-07 17:31:47 +02:00)

# %%
mode(dataset17[52:])
# Out:
# 714578.8666167259
# time: 3.18 ms (started: 2021-06-07 17:31:53 +02:00)

# %%
from collections import Counter
Counter(dataset17[52:])
# Out:
# Counter({714578.8666167259: 1,
#          714578.8646352291: 1,
#          714578.8625617027: 1,
#          714578.8652882576: 1,
#          714578.8653795719: 1,
#          714578.8654289246: 1,
#          714578.8647093773: 1,
#          714578.8646085262: 1,
#          714578.8661496639: 1,
#          714578.8649258614: 1,
#          714578.8629434109: 1,
#          714578.8618927002: 1,
#          714578.8673574924: 1,
#          714578.8640284538: 1,
#          714578.8643238544: 1,
#          714578.8663487434: 1,
#          714578.8658773899: 1,
#          714578.8623671532: 1,
#          714578.8637282848: 1,
#          714578.8646075726: 1,
#          714578.8653309345: 1,
#          714578.8626799583: 1,
#          714578.8646142483: 1,
#          714578.8652741909: 1,
#          714578.8661561012: 1,
#          714578.8637754917: 1,
#          714578.864836216: 1,
#          714578.8646295071: 1,
#          714578.864743948: 1,
#          714578.8659067154: 1,
#          714578.8642220497: 1,
#          714578.8638057709: 1,
#          714578.8663215637: 1,
#          714578.863830328: 1,
#          714578.863150835: 1,
#          714578.867459774: 1,
#          714578.8630151749: 1,
#          714578.8623142242: 1,
#          714578.8631279469: 1,
#          714578.8649687767: 1,
#          714578.8645756245: 1,
#          714578.8652245998: 1,
#          714578.8668334484: 1,
#          714578.8619399071: 1,
#          714578.8655748367: 1,
#          714578.8672020435: 1,
#          714578.8643889427: 1,
#          714578.8630707264: 1,
#          714578.8661050797: 1,
#          714578.8613665104: 1,
#          714578.864379406: 1,
#          714578.8654298782: 1,
#          714578.8659286499: 1,
#          714578.8636372089: 1,
#          714578.8643069267: 1,
#          714578.8635113239: 1,
#          714578.8665661812: 1,
#          714578.8637058735: 1,
#          714578.8636062145: 1,
#          714578.8635792732: 1,
#          714578.8646349907: 1,
#          714578.8627669811: 1,
#          714578.8641955853: 1,
#          714578.8665144444: 1,
#          714578.8646426201: 1,
#          714578.8643839359: 1,
#          714578.8643760681: 1,
#          714578.865417242: 1,
#          714578.8664662838: 1,
#          714578.866102457: 1,
#          714578.862193346: 1,
#          714578.8657040596: 1,
#          714578.8631725311: 1,
#          714578.8648068905: 1,
#          714578.8662514687: 1,
#          714578.8617796898: 1,
#          714578.8649442196: 1,
#          714578.8631937504: 1,
#          714578.8654880524: 1,
#          714578.8637640476: 1,
#          714578.8645608425: 1,
#          714578.8633832932: 1,
#          714578.8630759716: 1,
#          714578.8625113964: 1,
#          714578.8657097816: 1,
#          714578.8648586273: 1,
#          714578.862547636: 1,
#          714578.8648018837: 1,
#          714578.8634443283: 1,
#          714578.8630213737: 1,
#          714578.8629653454: 1,
#          714578.8634421825: 1,
#          714578.8625154495: 1,
#          714578.8646066189: 1,
#          714578.8644599915: 1,
#          714578.8626797199: 1,
#          714578.8646600246: 1,
#          714578.8627889156: 1})
# time: 8.78 ms (started: 2021-06-07 17:31:55 +02:00)

# %%
def printFreq2(data):
    counter = 0
    res = []
    
    for i, vali in enumerate(data):
        refNum = vali
        print(type(refNum))
        for j in range(i,len(data)):
            if (round(refNum,1) == round(data[j], 1)):
                counter += counter 
        res.append({round(refNum,1):counter})
        counter = 0
        
    return res
# Out:
# time: 1.14 ms (started: 2021-06-07 17:31:56 +02:00)

# %%
printFreq2(dataset17)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# [{2.4: 0},
#  {210512.1: 0},
#  {124655.1: 0},
#  {122965.6: 0},
#  {121257.0: 0},
#  {117726.1: 0},
#  {113192.7: 0},
#  {111053.7: 0},
#  {110265.8: 0},
#  {110251.7: 0},
#  {108698.8: 0},
#  {107570.5: 0},
#  {107470.8: 0},
#  {106722.4: 0},
#  {106337.2: 0},
#  {106134.6: 0},
#  {105504.3: 0},
#  {104844.1: 0},
#  {104717.5: 0},
#  {103512.0: 0},
#  {104045.8: 0},
#  {102832.9: 0},
#  {102134.9: 0},
#  {101087.7: 0},
#  {100903.0: 0},
#  {100346.3: 0},
#  {99737.0: 0},
#  {99996.5: 0},
#  {99444.5: 0},
#  {99781.0: 0},
#  {99434.0: 0},
#  {97893.0: 0},
#  {98551.1: 0},
#  {97448.4: 0},
#  {97839.6: 0},
#  {100028.3: 0},
#  {99371.1: 0},
#  {96283.9: 0},
#  {97970.1: 0},
#  {95039.0: 0},
#  {93946.2: 0},
#  {94775.9: 0},
#  {93935.8: 0},
#  {93861.1: 0},
#  {93727.3: 0},
#  {92724.0: 0},
#  {92131.1: 0},
#  {92985.5: 0},
#  {96429.7: 0},
#  {90895.2: 0},
#  {93413.9: 0},
#  {128751.6: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0},
#  {128741.0: 0}]
# time: 52.4 ms (started: 2021-06-02 08:57:48 +02:00)

# %%
import math
math.isclose(1.000001,1.00000)
# Out:
# False
# time: 2.9 ms (started: 2021-06-02 09:01:59 +02:00)

# %%
def printFreqIsClose(data):
    counter = 0
    res = []
    
    for i, vali in enumerate(data):
        refNum = vali
        print(type(refNum))
        for j in range(i,len(data)):
            if math.isClose(refNum,1) == round(data[j], 1)):
                counter += counter 
        res.append({round(refNum,1):counter})
        counter = 0
        
    return res
